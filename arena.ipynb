# %%
from game import *
from connect4_helper import *
from connect4_supervised_agent import *
from connect4_game import *
from connect4_MCTS_agent import *
from connect4_human_agent import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
supervised_agent =  Connect4SupervisedAgent()

# %%
MCTS_agent = Connect4MCTSAgent()

# %%
human_agent = Connect4HumanAgent()

# %%
print(play_games(Connect4MCTSAgent(100,supervised_agent), Connect4MCTSAgent(100), 100, True))
# Out:
# Game 0
# {'agent1': 0, 'agent2': 0, 'draws': 0}
# /Users/alberttroussard/Documents/connect4project/connect4_supervised_agent.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_hat = self.model(torch.tensor(input, device='mps').type(torch.float32).view(1,3,6,7))
# Game 1
# {'agent1': 1, 'agent2': 0, 'draws': 0}
# Game 2
# {'agent1': 1, 'agent2': 1, 'draws': 0}
# Game 3
# {'agent1': 1, 'agent2': 2, 'draws': 0}
# Game 4
# {'agent1': 1, 'agent2': 3, 'draws': 0}
# Game 5
# {'agent1': 1, 'agent2': 4, 'draws': 0}
# Game 6
# {'agent1': 1, 'agent2': 5, 'draws': 0}
# Game 7
# {'agent1': 2, 'agent2': 5, 'draws': 0}
# Game 8
# {'agent1': 3, 'agent2': 5, 'draws': 0}
# Game 9
# {'agent1': 3, 'agent2': 6, 'draws': 0}
# Game 10
# {'agent1': 3, 'agent2': 7, 'draws': 0}
# Game 11
# {'agent1': 3, 'agent2': 8, 'draws': 0}
# Game 12
# {'agent1': 3, 'agent2': 9, 'draws': 0}
# Game 13
# {'agent1': 3, 'agent2': 10, 'draws': 0}
# Game 14
# {'agent1': 3, 'agent2': 11, 'draws': 0}
# Game 15
# {'agent1': 4, 'agent2': 11, 'draws': 0}
# Game 16
# {'agent1': 4, 'agent2': 11, 'draws': 1}
# Game 17
# {'agent1': 4, 'agent2': 12, 'draws': 1}
# Game 18
# {'agent1': 4, 'agent2': 12, 'draws': 2}
# Game 19
# {'agent1': 5, 'agent2': 12, 'draws': 2}
# Game 20
# {'agent1': 5, 'agent2': 13, 'draws': 2}
# Game 21
# {'agent1': 6, 'agent2': 13, 'draws': 2}
# Game 22
# {'agent1': 7, 'agent2': 13, 'draws': 2}
# Game 23
# {'agent1': 8, 'agent2': 13, 'draws': 2}
# Game 24
# {'agent1': 9, 'agent2': 13, 'draws': 2}
# Game 25
# {'agent1': 9, 'agent2': 13, 'draws': 3}
# Game 26
# {'agent1': 10, 'agent2': 13, 'draws': 3}
# Game 27
# {'agent1': 11, 'agent2': 13, 'draws': 3}
# Game 28
# {'agent1': 11, 'agent2': 14, 'draws': 3}
# Game 29
# {'agent1': 12, 'agent2': 14, 'draws': 3}
# Game 30
# {'agent1': 12, 'agent2': 15, 'draws': 3}
# Game 31
# {'agent1': 12, 'agent2': 16, 'draws': 3}
# Game 32
# {'agent1': 13, 'agent2': 16, 'draws': 3}
# Game 33
# {'agent1': 14, 'agent2': 16, 'draws': 3}
# Game 34
# {'agent1': 14, 'agent2': 16, 'draws': 4}
# Game 35
# {'agent1': 14, 'agent2': 17, 'draws': 4}
# Game 36
# {'agent1': 15, 'agent2': 17, 'draws': 4}
# Game 37
# {'agent1': 15, 'agent2': 18, 'draws': 4}
# Game 38
# {'agent1': 16, 'agent2': 18, 'draws': 4}
# Game 39
# {'agent1': 17, 'agent2': 18, 'draws': 4}
# Game 40
# {'agent1': 17, 'agent2': 19, 'draws': 4}
# Game 41
# {'agent1': 17, 'agent2': 20, 'draws': 4}
# Game 42
# {'agent1': 18, 'agent2': 20, 'draws': 4}
# Game 43
# {'agent1': 19, 'agent2': 20, 'draws': 4}
# Game 44
# {'agent1': 19, 'agent2': 21, 'draws': 4}
# Game 45
# {'agent1': 20, 'agent2': 21, 'draws': 4}
# Game 46
# {'agent1': 20, 'agent2': 21, 'draws': 5}
# Game 47
# {'agent1': 20, 'agent2': 22, 'draws': 5}
# Game 48
# {'agent1': 21, 'agent2': 22, 'draws': 5}
# Game 49
# {'agent1': 22, 'agent2': 22, 'draws': 5}
# Game 50
# {'agent1': 22, 'agent2': 23, 'draws': 5}
# Game 51
# {'agent1': 22, 'agent2': 24, 'draws': 5}
# Game 52
# {'agent1': 22, 'agent2': 25, 'draws': 5}
# Game 53
# {'agent1': 23, 'agent2': 25, 'draws': 5}
# Game 54
# {'agent1': 23, 'agent2': 26, 'draws': 5}
# Game 55
# {'agent1': 24, 'agent2': 26, 'draws': 5}
# Game 56
# {'agent1': 25, 'agent2': 26, 'draws': 5}
# Game 57
# {'agent1': 26, 'agent2': 26, 'draws': 5}
# Game 58
# {'agent1': 27, 'agent2': 26, 'draws': 5}
# Game 59
# {'agent1': 28, 'agent2': 26, 'draws': 5}
# Game 60
# {'agent1': 28, 'agent2': 27, 'draws': 5}
# Game 61
# {'agent1': 28, 'agent2': 27, 'draws': 6}
# Game 62
# {'agent1': 28, 'agent2': 27, 'draws': 7}
# Game 63
# {'agent1': 29, 'agent2': 27, 'draws': 7}
# Game 64
# {'agent1': 29, 'agent2': 28, 'draws': 7}
# Game 65
# {'agent1': 29, 'agent2': 29, 'draws': 7}
# Game 66
# {'agent1': 29, 'agent2': 30, 'draws': 7}
# Game 67
# {'agent1': 29, 'agent2': 31, 'draws': 7}
# Game 68
# {'agent1': 29, 'agent2': 32, 'draws': 7}
# Game 69
# {'agent1': 29, 'agent2': 33, 'draws': 7}
# Game 70
# {'agent1': 29, 'agent2': 33, 'draws': 8}
# Game 71
# {'agent1': 29, 'agent2': 34, 'draws': 8}
# Game 72
# {'agent1': 29, 'agent2': 35, 'draws': 8}
# Game 73
# {'agent1': 29, 'agent2': 36, 'draws': 8}
# Game 74
# {'agent1': 29, 'agent2': 37, 'draws': 8}
# Game 75
# {'agent1': 29, 'agent2': 38, 'draws': 8}
# Game 76
# {'agent1': 30, 'agent2': 38, 'draws': 8}
# Game 77
# {'agent1': 31, 'agent2': 38, 'draws': 8}
# Game 78
# {'agent1': 31, 'agent2': 39, 'draws': 8}
# Game 79
# {'agent1': 32, 'agent2': 39, 'draws': 8}
# Game 80
# {'agent1': 33, 'agent2': 39, 'draws': 8}
# Game 81
# {'agent1': 33, 'agent2': 40, 'draws': 8}
# Game 82
# {'agent1': 33, 'agent2': 41, 'draws': 8}
# Game 83
# {'agent1': 33, 'agent2': 42, 'draws': 8}
# Game 84
# {'agent1': 34, 'agent2': 42, 'draws': 8}
# Game 85
# {'agent1': 35, 'agent2': 42, 'draws': 8}
# Game 86
# {'agent1': 36, 'agent2': 42, 'draws': 8}
# Game 87
# {'agent1': 37, 'agent2': 42, 'draws': 8}
# Game 88
# {'agent1': 37, 'agent2': 43, 'draws': 8}
# Game 89
# {'agent1': 38, 'agent2': 43, 'draws': 8}
# Game 90
# {'agent1': 39, 'agent2': 43, 'draws': 8}
# Game 91
# {'agent1': 39, 'agent2': 44, 'draws': 8}
# Game 92
# {'agent1': 39, 'agent2': 45, 'draws': 8}
# Game 93
# {'agent1': 40, 'agent2': 45, 'draws': 8}
# Game 94
# {'agent1': 40, 'agent2': 45, 'draws': 9}
# Game 95
# {'agent1': 41, 'agent2': 45, 'draws': 9}
# Game 96
# {'agent1': 42, 'agent2': 45, 'draws': 9}
# Game 97
# {'agent1': 42, 'agent2': 46, 'draws': 9}
# Game 98
# {'agent1': 42, 'agent2': 46, 'draws': 10}
# Game 99
# {'agent1': 42, 'agent2': 46, 'draws': 11}
# {'agent1': 43, 'agent2': 46, 'draws': 11}
