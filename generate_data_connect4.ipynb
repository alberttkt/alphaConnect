# %%
def show_board(state):
    a = state.get_tensors()[0]
    for i in range(5,-1,-1):
        for j in range(7):
            c = "." if a[i][j] == -1 else "X" if a[i][j] == 1 else "O"
            print(c, end=' ')
        print()

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from game import *
import random

State = ConnectState
state = State.sample_initial_state()
for _ in range(10):

    # The current player has to take an action
    player = state.player

    # For debugging and serialization, a game-dependent JSON object is provided
    json_like = state.to_json()

    # For modelling features, a game-dependent tuple of NumPy arrays is provided
    arrays = state.get_tensors()

    # At least one action is available
    actions = state.actions
    #print([action.to_json() for action in actions])
    action = random.choice(actions)

    # States and actions are immutable, the next is a new object
    # Note: similar to the initial state, the next state may be non-deterministic
    state = action.sample_next_state()

# %%
show_board(state)
# Out:
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# O . . X . O X
# X O . O O X X

# %%
from connect4_agent import *

# def get_game(agent:Connect4Agent):
#     state = State.sample_initial_state()
#     s = ''
#     good_game = False
#     nb_moves = random.randint(2, 41)
#     print(nb_moves)
#     while not good_game:

#         state = State.sample_initial_state()
#         s = ''
        
#         for _ in range(nb_moves):
#             if state.has_ended:
#                 break
#             action = agent.sample_move(state)
#             s += f"{action.to_json()+1}"
#             state = action.sample_next_state()
#         if state.has_ended:
#             continue
#         good_game = True

#     return s

def get_game(set,agent:Connect4Agent):
    state = State.sample_initial_state()
    s = ''
    good_game = False
    while not good_game:
        print(len(set))
        state = State.sample_initial_state()
        s = ''
        while not state.has_ended:
            action = agent.sample_move(state)
            s += f"{action.to_json()+1}"
            set.add(s)
            state = action.sample_next_state()
        if state.has_ended:
            continue
        good_game = True
    
    set.add(s)

# %%
games = set()

# %%
from connect4_MCTS_agent import Connect4MCTSAgent

agent = Connect4MCTSAgent(iterations=1000)

# %%
print(len(games))
while len(games) < 100000:
    get_game(games,agent)
    print(len(games))
# Out:
# 2742
# 2742
# 2762
# 2782
# 2797
# 2813
# 2826
# 2851
# 2874
# 2881
# 2914
# 2953
# 2964
# 2995
# 3036
# 3054
# 3079
# 3109
# 3118
# 3142
# 3174
# 3199
# 3227
# 3239
# 3266
# 3291
# 3307
# 3332
# 3352
# 3380
# 3413
# 3439
# 3462
# 3483
# 3501
# 3527
# 3565
# 3585
# 3611
# 3651
# 3678
# 3703
# 3717
# 3737
# 3762
# 3799
# 3824
# 3848
# 3866
# 3883
# 3896
# 3921
# 3953
# 3975
# 3997
# 4019
# 4046
# 4086
# 4120
# 4153
# 4192
# 4211
# 4233
# 4257
# 4281
# 4321
# 4354
# 4372
# 4410
# 4442
# 4455
# 4493
# 4519
# 4557
# 4576
# 4599
# 4628
# 4658
# 4691
# 4723
# 4742
# 4758
# 4780
# 4818
# 4850
# 4868
# 4876
# 4907
# 4919
# 4944
# 4972
# 4988
# 5021
# 5046
# 5078
# 5104
# 5127
# 5166
# 5201
# 5233
# 5260
# 5297
# 5313
# 5334
# 5372
# 5408
# 5432
# 5458
# 5491
# 5511
# 5546
# 5584
# 5611
# 5648
# 5672
# 5692
# 5714
# 5746
# 30270
# 30310
# 30327
# 30354
# 30371
# 30389
# 30408
# 30429
# 30460
# 30485
# 30507
# 30534
# 30550
# 30582
# 30600
# 30624
# 30659
# 30697
# 30700
# 30734
# 30759
# 30795
# 30826
# 30861
# 30900
# 30917
# 30944
# 30965
# 30996
# 31029
# 31047
# 31070
# 31088
# 31122
# 31149
# 31186
# 31196
# 31215
# 31240
# 31243
# 31264
# 31300
# 31319
# 31347
# 31368
# 31407
# 31426
# 31441
# 31445
# 31472
# 31505
# 31533
# 31570
# 31593
# 31611
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 print(len(games))
#       2 while len(games) < 100000:
# ----> 3     get_game(games,agent)
#       4     print(len(games))
#
# Cell In[9], line 35, in get_game(set, agent)
#      33 s = ''
#      34 while not state.has_ended:
# ---> 35     action = agent.sample_move(state)
#      36     s += f"{action.to_json()+1}"
#      37     set.add(s)
#
# File ~/Documents/connect4project/connect4_agent.py:14, in Connect4Agent.sample_move(self, state)
#      13 def sample_move(self, state):
# ---> 14     moves_proba_dict = self.play(state)
#      15     threshold = random.random()
#      16     cumulative = 0
#
# File ~/Documents/connect4project/connect4_MCTS_agent.py:71, in Connect4MCTSAgent.play(self, initial_state)
#      69 game_length = node.depth
#      70 while not state.has_ended:
# ---> 71     action = self.inner_agent.sample_move(state)
#      72     state = action.sample_next_state()
#      73     game_length += 1
#
# File ~/Documents/connect4project/connect4_agent.py:14, in Connect4Agent.sample_move(self, state)
#      13 def sample_move(self, state):
# ---> 14     moves_proba_dict = self.play(state)
#      15     threshold = random.random()
#      16     cumulative = 0
#
# File ~/Documents/connect4project/connect4_random_agent.py:10, in Connect4RandomAgent.play(self, state)
#       8 def play(self, state):
#       9     l= len(state.actions)
# ---> 10     actions = list(state.actions)
#      11     random.shuffle(actions)
#      12     d= {action.to_json(): 1.0/l for action in actions}
#
# KeyboardInterrupt:

# %%
print({i:len(list(filter(lambda x: len(x) == i, games))) for i in range(1,43)})
# Out:
# {1: 7, 2: 49, 3: 332, 4: 937, 5: 1154, 6: 1183, 7: 1187, 8: 1179, 9: 1177, 10: 1169, 11: 1168, 12: 1164, 13: 1162, 14: 1157, 15: 1151, 16: 1140, 17: 1126, 18: 1109, 19: 1091, 20: 1053, 21: 1017, 22: 965, 23: 915, 24: 868, 25: 815, 26: 759, 27: 719, 28: 677, 29: 617, 30: 570, 31: 538, 32: 496, 33: 462, 34: 421, 35: 386, 36: 352, 37: 320, 38: 287, 39: 256, 40: 205, 41: 152, 42: 122}

# %%
with open('inputs.txt', 'w') as f:
    for i in games:
        f.write(i+'\n')

# %%
file = open('data.csv', 'w')
for i in range(8):
    fi = open(f'output/output{i}.txt', 'r')
    for line in fi:
        words = line.split()
        moves = words[0]
        result = [int(x) for x in words[1:]]
        state = State.sample_initial_state()

        for move in moves:
            for action in state.actions:
                if int(action.to_json()) == int(move)-1:
                    state = action.sample_next_state()
                    break
        best_score = max(result)
        best_moves = [i for i, j in enumerate(result) if j == best_score]
        file.write(f"{",".join(map(str,state.get_tensors()[0].flatten()))},{''.join(map(str, best_moves))}\n")
